0.67926, 0.26155, 0.25511, 0.68111, 0.84615, 0.142, 0.94311, 0.77359, 0.97812, 0.94359, 0.48097, 0.28917, 0.48534, 0.99835, 0.18508, 0.34113, 0.84046, 0.45082, 0.93437, 0.35524, 0.57863, 0.25802, 0.17022, 0.0698, 0.29752, 0.1895, 0.89655, 0.53557, 0.65727, 0.82727, 0.67977, 0.11585, 0.38056, 0.56587, 0.64878, 0.48641, 0.25252, 0.61233, 0.49499, 0.63553, 0.12082, 0.98619, 0.4723, 0.864, 0.89562, 0.51947, 0.39712, 0.7851, 0.54956, 0.8567, 0.64835, 0.3246, 0.11781, 0.45492, 0.16741, 0.7208, 0.69803, 0.58366, 0.4582, 0.52446, 0.45036, 0.32495, 0.58712, 0.59888, 0.59747, 0.57332, 0.18308, 0.11983, 0.42452, 0.03579, 0.43749, 0.5756, 0.27915, 0.23192, 0.10426, 0.76696, 0.57152, 0.49371, 0.49978, 0.80719, 0.77429, 0.96571, 0.50297, 0.12209, 0.42262, 0.60495, 0.55523, 0.44993, 0.11417, 0.18095, 0.66047, 0.84148, 0.50908, 0.27575, 0.38509, 0.66004, 0.33002, 0.28389, 0.85801, 0.58138, 0.36214, 0.41238, 0.77062, 0.59379, 0.4531, 0.68077, 0.37684, 0.99804, 0.51305, 0.92108, 0.49307, 0.40741, 0.51465, 0.77784, 0.49821, 0.7477, 0.49306, 0.7081, 0.33367, 0.25718, 0.54593, 0.98137, 0.50337, 0.48662, 0.83342, 0.67968, 0.07369, 0.29932, 0.57819, 0.69758, 0.67356, 0.87105, 0.06538, 0.74209, 0.49438, 0.6901, 0.64267, 0.33275, 0.29005, 0.55724, 0.7202, 0.80157, 0.37698, 0.58576, 0.77063, 0.2931, 0.63407, 0.20144, 0.32912, 0.76437, 0.50274, 0.14255, 0.99332, 0.98491, 0.98689, 0.45989, 0.42339, 0.53674, 0.65292, 0.51673, 0.34198, 0.8144, 0.62974, 0.98885, 0.53426, 0.02493, 0.60876, 0.86454, 0.84787, 0.18785, 0.84388, 0.44457, 0.19298, 0.13519, 0.15151, 0.34223, 0.54224, 0.51149, 0.91056, 0.4833, 0.9308, 0.77377, 0.06243, 0.10605, 0.45633, 0.19157, 0.11103, 0.76128, 0.27898, 0.84692, 0.12277, 0.31226, 0.6214, 0.63435, 0.72654, ...

# %%
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005
rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.grid(which="major", linewidth=1.2, color="black")
ax_scatter.grid(which="minor", linestyle="--", color="green", linewidth=1)
ax_scatter.tick_params(which='major', length=10, width=2)
ax_histx = plt.axes(rect_histx)
ax_histx.grid(True)
ax_histx.tick_params(direction='in', labelbottom=False)

ax_scatter.scatter(a, b)
ax_histx.hist(a)

ax_histx.set_xlim(ax_scatter.get_xlim())

plt.show()

# %%
m = math.fsum(a) / 2000
print("Мат. ожидание равно: {}".format(m))
# Out:
# Мат. ожидание равно: 0.49928995

# %%
sum = 0
for i in range(len(a)):
    sum += (a[i] - m) ** 2
d = sum / 2000
print("Дисперсия равна: {}".format(d))
# Out:
# Дисперсия равна: 0.08215546863812001
