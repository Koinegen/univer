# %%
from lib.BRV import random
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
count = 600
boom = a = random(count=count)
b = [i for i in range(count)]
# Out:
# 0.5202498435974121

# %%
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005
rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.grid(which="major", linewidth=1.2, color="black")
ax_scatter.grid(which="minor", linestyle="--", color="green", linewidth=1)
ax_scatter.tick_params(which='major', length=10, width=2)
ax_histx = plt.axes(rect_histx)
ax_histx.grid(True)
ax_histx.tick_params(direction='in', labelbottom=False)


ax_scatter.scatter(a, b)
bins = 10



ax_histx.hist(a, bins, stacked=True, normed=True)

ax_histx.set_xlim(ax_scatter.get_xlim())

plt.show()

# %%
m = math.fsum(a) / count
print("Мат. ожидание равно: {}".format(m))
# Out:
# Мат. ожидание равно: 0.50543795

# %%
result = 0
for i in range(len(a)):
    result += (a[i] - m) ** 2
d = result / count
print("Дисперсия равна: {}".format(d))
# Out:
# Дисперсия равна: 0.0870120821799643

# %%
s = 2
b = []
for num, chislo in enumerate(list(boom)):
    if num + s < len(boom):
        b.append(chislo * a[num + s])
result = sum(b)
r = 1 / 12 * result / (count - s)
print("Коэфициент коррелляции: {}".format(r))
# Out:
# Коэфициент коррелляции: 0.020960399299679487
